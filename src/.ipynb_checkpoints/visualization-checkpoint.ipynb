# %%
#importing necessary libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %run preprocessing.ipynb
# %run model_training.ipynb
# Out:
# [2019]
# [2019]

# %%
train_df=pd.read_excel('../data/Train_set.xlsx')
test_df=pd.read_excel('../data/Test_set.xlsx')
df=pd.concat([train_df,test_df],axis=0,ignore_index=True)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
sns.scatterplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
#locating outliers and handling them in preprocessing.py     
sns.boxplot(y=df['Price'])
plt.show()

# %%
#histogram for distribution of price
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
#Box plot of Airplane agains price
plt.figure(figsize=(20,6))
sns.boxplot(x='Airline', y='Price', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#Violin plot to visualize the distribution of numerical values across diffrent categorical features
plt.figure(figsize=(30,6))
sns.violinplot(x=df['Airline'],y=df['Price'],data=df)
# Out:
# <Axes: xlabel='Airline', ylabel='Price'>

# %%
#plotting pairplot  for some important features
sns.pairplot(new_df_lr[['Price','Total_Stops','Duration_in_time']])

# %%
#Generating heatmap to visualize metrices,confusion metrics
new_df_lr.columns
# Out:
# Index(['Total_Stops', 'Price', 'journey_day', 'journey_month',
#        'Duration_in_time', 'arrival_time_hour', 'arrival_time_minute',
#        'arrival_day', 'arrival_month', 'Departure_hour', 'Departure_minute',
#        'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
#        'Airline_Jet Airways', 'Airline_Jet Airways Business',
#        'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
#        'Destination_Kolkata', 'Destination_New Delhi'],
#       dtype='object')

# %%
#plotting heatmap of some features
corr = new_df_lr[['Price','Total_Stops','Duration_in_time','arrival_day','Airline_Air India','Airline_Multiple carriers Premium economy']].corr()
plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()
